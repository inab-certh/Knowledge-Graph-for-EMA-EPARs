# %% [markdown]
# ## European Medicine Agency (EMA)
#
# The European Medicines Agency (EMA) is a decentralized agency of the European Union (EU) responsible for the scientific evaluation, supervision, and safety monitoring of medicines in the EU. EMA plays a crucial role in the public health domain by ensuring that all medicines available on the EU market are safe, effective, and of high quality.

# %% [markdown]
# ## Summary of product characteristics (SmPC)
#
# A document describing the properties and the officially approved conditions of use of a medicine. Summaries of product characteristics form the basis of information for healthcare professionals on how to use the medicine safely and effectively. Abbreviated as SmPC.
#
# <br/>
#
# ### Structure of an SmPC
# The structure of the SmPC is defined by the European pharmaceutical legislation. The information included in the SmPC should be product specific and can be cross-referenced to avoid any redundancy. It should be documented in a clear language and should not lead to any ambiguity. The SmPC is divided into 6 major sections:
#
# 1. Name of the product
# 2. Composition
# 3. Pharmaceutical Form
# 4. Clinical particulars – Includes therapeutic indications, recommendation for dosages and safety information
# 5. Pharmacological properties – Takes into account the therapeutic indications of the clinical elements and their potential adverse drug reactions
# 6. Pharmaceutical particulars – Includes Regulatory information related to the drug
#
# <br/>
#
# <img src="./images/structureSmPC.png" width="600px;">
#
# <br/>
# <br/>
#
# ### Prescribing medicines for special populations
# When prescribing medication to specific groups like children, the elderly, pregnant and breastfeeding women, and individuals with kidney or liver issues, it's
# crucial to exercise caution. The public documentation for medicines, especially the Summary of Product Characteristics (SmPC) and the package leaflets (PLs), often includes many of these essential precautions.
# <br/>
#
# <img src="./images/SmPC_authorization_process.png" width="800px;">
#
# When seeking marketing authorization, a company submits an application dossier that contains instructions for healthcare professionals on the safe and effective use of the medicine. In Europe, this is referred to as the Summary of Product Characteristics (SmPC). The SmPC must be regularly updated over the medicine's lifecycle to reflect new data on efficacy or safety. The figure above illustrates the connection between a medicine's development, the regulatory dossier with the initial proposed SmPC, the SmPC that gets approved, and subsequent updates to the SmPC.
#
#
# [1]: https://www.ema.europa.eu/en/glossary/summary-product-characteristics
# [2]: https://www.freyrsolutions.com/what-is-an-smpc

# %% [markdown]
# ### Project Overview
#
# Using natural language processing (NLP) techniquesto automatically extract adverse drug reactions from such unstructured textual information helps clinicalexperts to effectively and efficiently use them in daily practices. Such techniques have been developed for Structured Product Labels from the Food and Drug Administration (FDA), but there is no researchfocusing on extracting from the Summary of Product Characteristics.
#
#
# In this work, we built a naturallanguage processing pipeline that automatically scrapes the summary of product characteristics onlineand then extracts adverse drug reactions from them.
#
# <img src="./images/Project_Overview.png" width="300px;">

# %% [markdown]
# ##  STEP 1: Download medicine data and import them to Database
# You can download the European Medicines Agency's (EMA) medicine-related data published on this website in Excel table format from this page. EMA updates these medicine data tables once a day. The following two files need to be downloaded:
#
# <br/>
#
# * The file listing all medicines, **including the withdrawn and not authorised ones**, named medicines_output_european_public_assessment_reports_en.xlsx, found [here](https://www.ema.europa.eu/sites/default/files/Medicines_output_european_public_assessment_reports.xlsx)
#
# and
#
# * The file listing **all the URLs for the SmPCs**, named Product information URLs for member product-information-urls-member-states_en.xls, found [here](https://www.ema.europa.eu/documents/product-information/product-information-urls-member-states_en.xls)
#
#
# ##### Disclaimer
# The database is used purely to join the two csv. The view can also be done with dataframes without the need to use the database
#
# [3]: https://toolbox.eupati.eu/resources/prescribing-medicines-for-special-populations/?print=print
# [4]: https://www.ema.europa.eu/en/homepage

# %%
import os
import pandas as pd
import re
import sqlite3
import camelot

# Define the folder that you store the required xls
PATH = "./data"

MEDICINE_LIST = "medicines_output_european_public_assessment_reports_en.xlsx"
PRODUCT_URLS_LIST = "product-information-urls-member-states_en.xls"

# %%
medicinesOutputData = pd.read_excel(os.path.join(PATH, MEDICINE_LIST))
medicinesOutputData.head()

# %%
productInformationURLs = pd.read_excel(os.path.join(PATH, PRODUCT_URLS_LIST))
productInformationURLs.head()

# %%
conn = sqlite3.connect(os.path.join(PATH, "SmPCs.db"))

medicinesOutputData.to_sql('emaMedicinesOP', conn, if_exists='replace', index=False)
productInformationURLs.to_sql('emaProductInformationURLs', conn, if_exists='replace', index=False)

# %% [markdown]
# ## Step 2: Create csv with SmPCs URLs
#
#  The actual SmPCs information will be extracted from the joinedHumanAuthorisedProductURLsONLY.csv file which contains the URLs for the authorised medicines for human use.

# %%
joinedHumanAuthorisedProductURLsONLY = pd.read_sql("""
    SELECT [URL(currentwebsite)]
    FROM emaMedicinesOP
    LEFT JOIN emaProductInformationURLs 
    ON emaMedicinesOP.[Medicine name]=emaProductInformationURLs.[ProductName]
    WHERE  emaMedicinesOP.Category='Human'
      AND emaMedicinesOP.[Authorisation Status] ='Authorised';
""", conn)

joinedHumanAuthorisedProductURLsONLY.to_csv(os.path.join(PATH, "joinedHumanAuthorisedProductURLsONLY.csv"))

# %% [markdown]
# ## Step 3: Download SmPCs pdfs

# %%
import requests

# %%
urlsDF = pd.read_csv(os.path.join(PATH, "joinedHumanAuthorisedProductURLsONLY.csv"))
urlsDF.dropna(inplace = True)
urls = urlsDF['URL(currentwebsite)'].tolist()

# %%
for index, url in enumerate(urls):
    response = requests.get(url)
    file_name = url.split('/')[-1]

    print("Download ", index, " with name: ", file_name)

    if response.status_code == 200:
        with open(os.path.join(PATH, "pdfs", file_name), 'wb') as pdf_file:
            pdf_file.write(response.content)
    else:
        print(f"Failed to download the : {file_name}")

# %% [markdown]
# ### Step 4: Extract Tabulated Summary of Adverse Reactions from the 4.8 section
#
# This section should include all adverse reactions for which, after thorough assessment, a causal relationship between the medicinal product and the adverse event is at least a reasonable possibility. These ADRs should be all reactions from:
# * Clinical trials
# * Post-authorisation safety studies
# * Spontaneous reporting
#
# #####  The tabulated list of adverse reactions in section 4.8:
# * Introduce table with short paragraph stating source of safety database
# * Separate tables are acceptable in exceptional cases where adverse profiles markedly differ depending on the use of the product.
#
# #####  Structure of the table: general considerations
#
# * Table should be written according to MedDRA system organ classification (SOC)
# * A pragmatic approach to the location of terms should be taken in order to make the identification of adverse reactions simpler and clinically appropriate for the reader
# * Within each SOC, adverse reactions should be ranked under headings of frequency, most frequent reactions first
# * Frequency grouping, adverse reactions should be presented in order of decreasing seriousness
#
# ##### Frequency Grouping:
# * Very common (≥1/10)
# * Common (≥1/100 to <1/10)
# * Uncommon (≥1/1,000 to <1/100)
# * Rare (≥1/10,000 to <1/1,000)
# * Very rare (<1/10,000)
# * Frequency not known (cannot be estimated from the available data)
#
# #### SmPCs Examples
#
# <img src="./images/SmPCs_example.png" width="500px;">
#
#
# ## MedDRA
# MedDRA is a multilingual terminology allowing most users to operate in their native languages. The table below identifies the initial MedDRA version when each MedDRA language was made available to users.
#
# <br />
#
# <img src="./images/MedDRA_Hierarchy.png" width="500px;">
#
# <br />
#
# The most important reason to “code” data into a standardised terminology is to analyse it. A key benefit of MedDRA is in its support of straightforward as well as sophisticated analyses. MedDRA can be used to analyse individual medical events (e.g., “Influenza”) or issues involving a system, organ or aetiology (e.g., infections) using its hierarchical structure. MedDRA can be used for signal detection and monitoring of clinical syndromes whose symptoms encompass numerous systems or organs using its multiaxial hierarchy or through the special feature of Standardised MedDRA Queries.
#
# <br />
#
# ### MedDRA Hierarchy
#
# The structure of MedDRA is very logical. There are five levels to the MedDRA hierarchy, arranged from very specific to very general.
#
# <br />
#
# Download [MedDRA codes](https://www.ema.europa.eu/en/documents/other/meddra-important-medical-event-terms-list-version-261_en.xlsx) and extract the unique values from the SOC Name column

# %%
medra = pd.read_excel(os.path.join(PATH, "MedDRA", "meddra-important-medical-event-terms-list-version-261_en.xlsx"))
socList = [".*" + term.replace(",", "").replace(" ", ".*") + ".*" for term in medra['SOC Name'].unique()]
SOCListRegex = '(?:% s)' % '|'.join(socList)
regexSOC = re.compile(SOCListRegex)
regexSOC
# Out:
# re.compile(r'(?:.*Blood.*and.*lymphatic.*system.*disorders.*|.*Cardiac.*disorders.*|.*Congenital.*familial.*and.*genetic.*disorders.*|.*Endocrine.*disorders.*|.*Eye.*disorders.*|.*Gastrointestinal.*disorders.*|.*Hepatobiliary.*disorders.*|.*Immune.*system.*disorders.*|.*Infections.*and.*infestations.*|.*Injury.*poisoning.*and.*procedural.*complications.*|.*Investigations.*|.*Musculoskeletal.*and.*connective.*tissue.*disorders.*|.*Neoplasms.*benign.*malignant.*and.*unspecified.*(incl.*cysts.*and.*polyps).*|.*Nervous.*system.*disorders.*|.*Pregnancy.*puerperium.*and.*perinatal.*conditions.*|.*Renal.*and.*urinary.*disorders.*|.*Reproductive.*system.*and.*breast.*disorders.*|.*Respiratory.*thoracic.*and.*mediastinal.*disorders.*|.*Surgical.*and.*medical.*procedures.*|.*Vascular.*disorders.*|.*Ear.*and.*labyrinth.*disorders.*|.*General.*disorders.*and.*administration.*site.*conditions.*|.*Metabolism.*and.*nutrition.*disorders.*|.*Product.*issues.*|.*Psychiatric.*disorders.*|.*Skin.*and.*subcutaneous.*tissue.*disorders.*|.*Social.*circumstances.*)',
#            re.UNICODE)

# %%
extra_terms = ["Infections – bacterial" , "Infections – viral", "Infections – pathogen unspecified",  "Infections – fungal"]

# %%
medra = pd.read_excel(os.path.join(PATH, "MedDRA", "meddra-important-medical-event-terms-list-version-261_en.xlsx"))
ptList = list(medra['PT Name'].unique()) # + extra_terms
PTListRegex = '(?:% s)' % '|'.join(ptList) 
regexPT = re.compile(PTListRegex)
regexPT
# Out:
# re.compile(r"(?:Immune-mediated pancytopenia|Spleen hypoperfusion|Splenic haematoma|Thrombocytopenic purpura|Subendocardial haemorrhage|Cochlear hypoplasia|Congenital intrahepatic arterioportal fistula|Frontonasal dysplasia|Ovarioleukodystrophy|Paraduodenal hernia|Progressive myoclonic epilepsy|Pyriform aperture stenosis|Radial dysplasia|Systemic artery to pulmonary artery fistula|Thanatophoric dysplasia|Ulnar dimelia|Decompensated hypothyroidism|Haemorrhagic adrenal infarction|Pituitary xanthogranuloma|Polycystic ovarian syndrome|Pseudo Cushing's syndrome|Blepharokeratoconjunctivitis|Monocular vision|Phlyctenular keratoconjunctivitis|Postictal blindness|Vitreous haematoma|Abdominal wall haematoma|Chronic gastrointestinal bleeding|Chronic sclerosing sialadenitis|Colitis|Gastrooesophageal haemorrhage|Haemorrhagic intestinal infarction|Mesenteric vein aneurysm|Peritoneal haematoma|Hepatic haematoma|Immune effector cell-associated HLH-like syndrome|Immunotoxicity|Rhupus syndrome|Adenopathy syphilitic|Amoebic colitis|Bacterial abdominal infection|Bacterial dacryocystitis|Breast abscess|Bronchopulmonary aspergillosis allergic|Campylobacter colitis|Chlamydial pelvic inflammatory disease|Conjunctivitis fungal|Device related fungaemia|Enterocolitis viral|Epidemic polyarthritis|Fusarium endocarditis|Hepatic actinomycosis|Human immunodeficiency virus transmission|Influenza myocarditis|Lower respiratory tract infection|Microsporum infection|Papular pruritic eruption of HIV|Pleurisy viral|Pouchitis infective|Stenotrophomonas maltophilia pneumonia|Superinfection|Tuberculoma|Viral myositis|Zygomatic abscess|Arteriovenous fistula site haemorrhage|Arteriovenous graft site haemorrhage|Atypical fracture|Chance fracture|Complicated fracture|Ilium fracture|Periprosthetic fracture|Radiation leukoencephalopathy|Traumatic haematoma|Vascular graft haemorrhage|Cancer cells present|Fracture delayed union|Fracture malunion|Fracture nonunion|Pathological fracture|Advanced systemic mastocytosis|Anaplastic ganglioglioma|Follicular lymphoma recurrent|Follicular lymphoma refractory|HER2 low breast cancer|HER2 positive biliary tract cancer|HER2 positive bladder cancer|HER2 positive cervix cancer|HER2 positive colorectal cancer|HER2 positive endometrial cancer|HER2 positive ovarian cancer|HER2 positive pancreatic carcinoma|High grade B-cell lymphoma recurrent|High grade B-cell lymphoma refractory|Indolent systemic mastocytosis|Intraductal papillary mucinous neoplasm|Intratumoural haematoma|Optic nerve sheath meningioma|PD-L1 positive cancer|PD-L2 positive cancer|Pituicytoma|RET gene fusion cancer|Smouldering systemic mastocytosis|Spinal nerve sheath tumour|Uterine leiomyoma rupture|Hemiclonic seizure|Middle cerebral artery stroke|Occipital lobe epilepsy|Occipital lobe stroke|Parietal lobe stroke|Spinal epidural haematoma|Vertebrobasilar infarction|Postpartum haemorrhage|Immune-complex membranoproliferative glomerulonephritis|Renal haematoma|Cervix haematoma uterine|Ovarian haematoma|Scrotal haematocoele|Scrotal haemorrhage|Uterine haematoma|Mediastinal haematoma|Nasal cavity fistula|Pulmonary artery dissection|Fractured zygomatic arch elevation|Aorto-cardiac fistula|Immune-mediated vasculitis|Subclavian vein embolism|Acquired amegakaryocytic thrombocytopenia|Acquired factor IX deficiency|Acquired factor V deficiency|Acquired factor VIII deficiency|Acquired factor XI deficiency|Acquired haemoglobinopathy|Acquired haemophilia|Acquired thalassaemia|Acquired Von Willebrand's disease|Agranulocytosis|Allergic lymphangitis|Antiphospholipid syndrome|Aplasia pure red cell|Aplastic anaemia|Atypical haemolytic uraemic syndrome|Autoimmune anaemia|Autoimmune aplastic anaemia|Autoimmune haemolytic anaemia|Autoimmune heparin-induced thrombocytopenia|Autoimmune neutropenia|Autoimmune pancytopenia|B-cell aplasia|Bicytopenia|Blood loss anaemia|Bone marrow failure|Bone marrow infiltration|Bone marrow necrosis|Breakthrough haemolysis|Carboxyhaemoglobinaemia|Cardiac haemolytic ana ...
#            re.UNICODE)

# %%
def extract_table_rows(df):
    rows = []

    for row in df.itertuples():
        # First row contains the header
        if row[0] == 0:
            # Find the order of columns
            if "reaction".lower() in row[2].lower() else False:
                AD_index, F_index  = 2, 3
            else:
                AD_index, F_index  = 3, 2

        else:
            ad_reaction = row[AD_index].split('\n')
            freq = row[F_index].split('\n')
            
            for index, ad in enumerate(ad_reaction):
                ad_row = []
                ad_row.insert(0, row[1].replace('\n', ''))  
                ad_row.insert(1, ad_reaction[index].strip())
                ad_row.insert(2, freq[index].strip())
                rows.append(ad_row)
    return rows

# %%
# List all pdfs in the directory
pdfs_processed = []
pdfs_not_processed = []

for file in os.listdir(os.path.join(PATH, 'pdfs')): # ['abecma-epar-product-information_en.pdf']:
    
    if file.lower().endswith('.pdf'):
        filename = file.split('/')[-1].split('-')[0]
        fullpath = os.path.join(PATH, 'pdfs', file)
        
        print("Start Processing Filename: ", fullpath)
        
        tables = camelot.read_pdf(fullpath, pages='all', flavor='lattice', line_scale=80, shift_text = ['', 'l'], process_background=False)

        rows = []
        for i, table in enumerate(tables):
            # Convert table to a pandas DataFrame
            df = table.df
    
            # Search for regex in the first column
            matches = df[0].str.contains(regex, regex=True)
    
            # Check if any value in the column matches the regex pattern
            contains_regex = matches.any()

            if contains_regex:
                if len(df.columns) == 3:
                    # Case A: Dataframe consists of 3 columns
                    print("The file ", filename, " does have three columns table")
                    extracted_rows = extract_table_rows(df)
                    for row in extracted_rows:
                        rows.append(row)

                    pdfs_processed.append(fullpath)
                else:
                    print("The file ", filename, " does NOT have three columns table")
                    pdfs_not_processed.append(fullpath)
        if rows:
            pd.DataFrame(rows, columns=["SOC", "ADR", "FREQ"]).to_csv(os.path.join(PATH, "extracted_tables", filename + ".csv"), sep=';', encoding='utf-8', index=False)
            
# Create report

# %%
pattern = re.compile("System\s*organ\s*class", re.IGNORECASE)
freq_regex = re.compile("(?i)(Very common|Common|Uncommon|Rare|Very rare|Frequency not known)")


for file in [
    # 'abecma-epar-product-information_en.pdf',
    'abevmy-epar-product-information_en.pdf',
    #'abiraterone-accord-epar-product-information_en.pdf'
    ]: 

    if file.lower().endswith('.pdf'):
        filename = file.split('/')[-1].split('-')[0]
        fullpath = os.path.join(PATH, 'pdfs', file)
        
        print("Start Processing Filename: ", fullpath)

        tables = camelot.read_pdf(fullpath, pages='all', flavor='lattice', line_scale=80, shift_text = ['', 'l'], process_background=False)

        for i, table in enumerate(tables):
            df = table.df
            AD_list = []
            FR_list = []
            SOC_list = []
            
            # Tables that have SOC in the first row 
            if df.iloc[0].astype(str).str.contains(pattern).any():
                
                columns = df.iloc[0][0].split('\n')
                print("The table: ", i, "1st Row: " , df.iloc[0])
                print("The table: ", i, "Len 1st Row: " , len(df.iloc[0]))

        
                if len(df.iloc[0]) == 3:
                    print("Case A: Table has 3 columns SOC, AR, FR")
    
                    for index, row in df.iterrows():
                        if index == 0:
                            continue
                            
                        for item in row:
                            print("Item: ", item.replace("\n", ""))
                            if item:
                                if freq_regex.search(item):
                                    print("Add FR: ", item.split('\n'))
                                    FR_list += item.split('\n')
                                elif regexSOC.search(item.replace("\n", "")):
                                    print("Add SOC: ", item.split('\n'))
                                    SOC_list += item.split('\n')
                                else:
                                    print("Add AD: ", item.split('\n'))
                                    AD_list += item.split('\n')

                elif df.iloc[0].astype(str).str.contains(freq_regex).any():
                    print("Case B: Table has frequencies in the first row")
                    
                    for index, row in df.iterrows():
                        if index == 0:
                            frequencies_dict = row.to_dict()
                            frequencies_dict.pop(0)
                            print("Frequencies: ", frequencies_dict)
                            continue

                        count = 0
                        for item in row:
                            if count == 0:
                                count += 1
                                continue
                                
                            item.replace('\n', '')
                            print(f"Item {count} : {item}")

                            if item:
                                ar_list = [item.replace("\n", "") for item in item.split(',') if len(item) > 2]
                                AD_list += ar_list
                                FR_list += [frequencies_dict[count] for _ in range(len(ar_list))]

                            count += 1
                            
                pd.DataFrame({'ADR': AD_list, 'FREQ': FR_list}).to_csv(os.path.join(PATH, "extracted_tables", filename + ".csv"), sep=';', encoding='utf-8', index=False,  mode='a', header=False)
# Out:
# Start Processing Filename:  ./data/pdfs/abevmy-epar-product-information_en.pdf
# The table:  0 1st Row:  0    System organ \nclass
# 1             Very common
# 2                  Common
# 3                    Rare
# 4               Very rare
# 5               Not known
# Name: 0, dtype: object
# The table:  0 Len 1st Row:  6
# Case B: Table has frequencies in the first row
# Frequencies:  {1: 'Very common', 2: 'Common', 3: 'Rare', 4: 'Very rare', 5: 'Not known'}
# Item 1 :
# Item 2 : Sepsis, Abscessb,d,
# Cellulitis,
# Infection, Urinary
# tract infection
# AR list:  ['Sepsis', ' Abscessb', ' Cellulitis', ' Infection', ' Urinary tract infection']
# Item 3 : Necrotising
# fasciitisa
# AR list:  ['Necrotising fasciitisa']
# Item 4 :
# Item 5 :
# Item 1 : Febrile
# neutropenia,
# Leucopenia,
# Neutropeniab,
# Thrombocytopenia
# AR list:  ['Febrile neutropenia', ' Leucopenia', ' Neutropeniab', ' Thrombocytopenia']
# Item 2 : Anaemia,
# Lymphopenia
# AR list:  ['Anaemia', ' Lymphopenia']
# Item 3 :
# Item 4 :
# Item 5 :
# Item 1 :
# Item 2 : Hypersensitivity,
# infusion
# reactionsa,b,d
# AR list:  ['Hypersensitivity', ' infusion reactionsa']
# Item 3 : Anaphylactic
# shock
# AR list:  ['Anaphylactic shock']
# Item 4 :
# Item 5 :
# Item 1 : Anorexia,
# Hypomagnesaemia
# Hyponatraemia
# AR list:  ['Anorexia', ' Hypomagnesaemia Hyponatraemia']
# Item 2 : Dehydration
# AR list:  ['Dehydration']
# Item 3 :
# Item 4 :
# Item 5 :
# Item 1 : Peripheral sensory
# neuropathyb,
# Dysarthria,
# Headache,
# Dysguesia
# AR list:  ['Peripheral sensory neuropathyb', ' Dysarthria', ' Headache', ' Dysguesia']
# Item 2 : Cerebrovascular
# accident, Syncope,
# Somnolence
# AR list:  ['Cerebrovascular accident', ' Syncope', ' Somnolence']
# Item 3 : Posterior
# reversible
# encephalopathy
# syndromea,b,d
# AR list:  ['Posterior reversible encephalopathy syndromea']
# Item 4 : Hypertensive
# encephalopathya
# AR list:  ['Hypertensive encephalopathya']
# Item 5 :
# Item 1 : Eye disorder,
# Lacrimation
# increased
# AR list:  ['Eye disorder', ' Lacrimation increased']
# Item 2 :
# Item 3 :
# Item 4 :
# Item 5 :
# Item 1 :
# Item 2 : Congestive heart
# failureb,d,
# Supraventricular
# tachycardia
# AR list:  ['Congestive heart failureb', ' Supraventricular tachycardia']
# Item 3 :
# Item 4 :
# Item 5 :
# Item 1 : Hypertensionb,d,
# Thromboembolism
# (venous)b,d
# AR list:  ['Hypertensionb', ' Thromboembolism (venous)b']
# Item 2 : Thromboembolism
# (arterial)b,d,
# Haemorrhageb,d,
# Deep vein
# thrombosis
# AR list:  ['Thromboembolism (arterial)b', ' Haemorrhageb', ' Deep vein thrombosis']
# Item 3 :
# Item 4 :
# Item 5 : Renal thrombotic
# microangiopathy
# a,b, Aneurysms
# and artery
# dissections
# AR list:  ['Renal thrombotic microangiopathy a', ' Aneurysms and artery dissections']
# Item 1 : Dyspnoea,
# Rhinitis, Epistaxis,
# Cough
# AR list:  ['Dyspnoea', ' Rhinitis', ' Epistaxis', ' Cough']
# Item 2 : Pulmonary
# haemorrhage/
# haemoptysisb,d,
# Pulmonary
# embolism,
# Hypoxia,
# Dysphoniaa
# AR list:  ['Pulmonary haemorrhage/ haemoptysisb', ' Pulmonary embolism', ' Hypoxia', ' Dysphoniaa']
# Item 3 :
# Item 4 :
# Item 5 : Pulmonary
# hypertensiona,
# Nasal septum
# perforationa
# AR list:  ['Pulmonary hypertensiona', ' Nasal septum perforationa']
# The table:  1 1st Row:  0    System organ \nclass
# 1             Very common
# 2                  Common
# 3                    Rare
# 4               Very rare
# 5               Not known
# Name: 0, dtype: object
# The table:  1 Len 1st Row:  6
# Case B: Table has frequencies in the first row
# Frequencies:  {1: 'Very common', 2: 'Common', 3: 'Rare', 4: 'Very rare', 5: 'Not known'}
# Item 1 : Rectal
# haemorrhage,
# Stomatitis,
# Constipation,
# Diarrhoea, Nausea,
# Vomiting,
# Abdominal pain
# AR list:  ['Rectal haemorrhage', ' Stomatitis', ' Constipation', ' Diarrhoea', ' Nausea', ' Vomiting', ' Abdominal pain']
# Item 2 : Gastrointestinal
# perforationb,d,
# Intestinal
# perforation, Ileus,
# Intestinal
# obstruction, Recto-
# vaginal fistulaed,e,
# Gastrointestinal
# disorder,
# Proctalgia
# AR list:  ['Gastrointestinal perforationb', ' Intestinal perforation', ' Ileus', ' Intestinal obstruction', ' Recto- vaginal fistulaed', ' Gastrointestinal disorder', ' Proctalgia']
# Item 3 :
# Item 4 :
# Item 5 : Gastrointestinal
# ulcera
# AR list:  ['Gastrointestinal ulcera']
# Item 1 :
# Item 2 :
# Item 3 :
# Item 4 :
# Item 5 : Gallbladder
# perforationa,b
# AR list:  ['Gallbladder perforationa']
# Item 1 : Wound healing
# complicationsb,d,
# Exfoliative
# dermatitis,
# Dry skin, Skin
# discoloration
# AR list:  ['Wound healing complicationsb', ' Exfoliative dermatitis', ' Dry skin', ' Skin discoloration']
# Item 2 : Palmar-plantar
# erythrodysaesthe-
# sia syndrome
# AR list:  ['Palmar-plantar erythrodysaesthe- sia syndrome']
# Item 3 :
# Item 4 :
# Item 5 :
# Item 1 : Arthralgia Myalgia Fistulab,d,
# AR list:  ['Arthralgia Myalgia Fistulab']
# Item 2 : Muscular
# weakness, Back
# pain
# AR list:  ['Muscular weakness', ' Back pain']
# Item 3 :
# Item 4 :
# Item 5 : Osteonecrosis of
# the jawa,b,
# Non-mandibular
# osteonecrosisa,f
# AR list:  ['Osteonecrosis of the jawa', ' Non-mandibular osteonecrosisa']
# Item 1 : Proteinuriab,d
# AR list:  ['Proteinuriab']
# Item 2 :
# Item 3 :
# Item 4 :
# Item 5 :
# Item 1 : Ovarian failureb,c,d  Pelvic Pain
# AR list:  ['Ovarian failureb', 'd  Pelvic Pain']
# Item 2 :
# Item 3 :
# Item 4 :
# Item 5 :
# Item 1 :
# Item 2 :
# Item 3 :
# Item 4 :
# Item 5 : Foetal
# abnormalitiesa,b
# AR list:  ['Foetal abnormalitiesa']
# Item 1 : Asthenia, Fatigue,
# Pyrexia, Pain,
# Mucosal
# inflammation
# AR list:  ['Asthenia', ' Fatigue', ' Pyrexia', ' Pain', ' Mucosal inflammation']
# Item 2 : Lethargy
# AR list:  ['Lethargy']
# Item 3 :
# Item 4 :
# Item 5 :
# Item 1 : Weight decreased
# AR list:  ['Weight decreased']
# Item 2 :
# Item 3 :
# Item 4 :
# Item 5 :
# The table:  2 1st Row:  0    System organ \nclass
# 1             Very common
# 2                  Common
# 3                    Rare
# 4               Not known
# Name: 0, dtype: object
# The table:  2 Len 1st Row:  5
# Case B: Table has frequencies in the first row
# Frequencies:  {1: 'Very common', 2: 'Common', 3: 'Rare', 4: 'Not known'}
# Item 1 :
# Item 2 : Sepsis, Cellulitis,
# Abscessa,b, Infection,
# Urinary tract infection
# AR list:  ['Sepsis', ' Cellulitis', ' Abscessa', ' Infection', ' Urinary tract infection']
# Item 3 :
# Item 4 : Necrotising fasciitisc
# AR list:  ['Necrotising fasciitisc']
# Item 1 : Febrile neutropenia,
# Leucopenia,
# Neutropeniaa,
# Thrombocytopenia
# AR list:  ['Febrile neutropenia', ' Leucopenia', ' Neutropeniaa', ' Thrombocytopenia']
# Item 2 : Anaemia,
# Lymphopenia
# AR list:  ['Anaemia', ' Lymphopenia']
# Item 3 :
# Item 4 :
# Item 1 :
# Item 2 : Hypersensitivity,
# Infusion reactionsa,b,c
# AR list:  ['Hypersensitivity', ' Infusion reactionsa']
# Item 3 : Anaphylactic
# shock
# AR list:  ['Anaphylactic shock']
# Item 4 :
# Item 1 :
# Item 2 : Dehydration,
# Hyponatraemia
# AR list:  ['Dehydration', ' Hyponatraemia']
# Item 3 :
# Item 4 :
# Item 1 : Peripheral sensory
# neuropathya
# AR list:  ['Peripheral sensory neuropathya']
# Item 2 : Cerebrovascular
# accident, Syncope,
# Somnolence, Headache
# AR list:  ['Cerebrovascular accident', ' Syncope', ' Somnolence', ' Headache']
# Item 3 :
# Item 4 : Posterior reversible
# encephalopathy
# syndrome a,b,c,
# Hypertensive
# encephalopathyc
# AR list:  ['Posterior reversible encephalopathy syndrome a', ' Hypertensive encephalopathyc']
# Item 1 :
# Item 2 : Congestive heart
# failurea,b,
# Supraventricular
# tachycardia
# AR list:  ['Congestive heart failurea', ' Supraventricular tachycardia']
# Item 3 :
# Item 4 :
# Item 1 : Hypertensiona,b
# AR list:  ['Hypertensiona']
# Item 2 : Thromboembolism
# arteriala,b,
# Haemorrhagea,b,
# Thromboembolism
# (venous)a,b , Deep vein
# thrombosis
# AR list:  ['Thromboembolism arteriala', ' Haemorrhagea', ' Thromboembolism (venous)a', 'b ', ' Deep vein thrombosis']
# Item 3 :
# Item 4 : Renal thrombotic
# microangiopathyb,c,
# Aneurysms and
# artery dissections
# AR list:  ['Renal thrombotic microangiopathyb', ' Aneurysms and artery dissections']
# Item 1 :
# Item 2 : Pulmonary
# haemorrhage/
# haemoptysisa,b,
# Pulmonary embolism,
# Epistaxis, Dyspnoea,
# Hypoxia
# AR list:  ['Pulmonary haemorrhage/ haemoptysisa', ' Pulmonary embolism', ' Epistaxis', ' Dyspnoea', ' Hypoxia']
# Item 3 :
# Item 4 : Pulmonary
# hypertensionc, Nasal
# septum perforationc
# AR list:  ['Pulmonary hypertensionc', ' Nasal septum perforationc']
# Item 1 : Diarrhoea, Nausea,
# Vomiting,
# Abdominal pain
# AR list:  ['Diarrhoea', ' Nausea', ' Vomiting', ' Abdominal pain']
# Item 2 : Intestinal perforation,
# Ileus, Intestinal
# obstruction, Recto-
# vaginal fistulaec,d,
# Gastrointestinal
# disorder, Stomatitis,
# Proctalgia
# AR list:  ['Intestinal perforation', ' Ileus', ' Intestinal obstruction', ' Recto- vaginal fistulaec', ' Gastrointestinal disorder', ' Stomatitis', ' Proctalgia']
# Item 3 :
# Item 4 : Gastrointestinal
# perforationa,b,
# Gastrointestinal
# ulcerc, Rectal
# haemorrhage
# AR list:  ['Gastrointestinal perforationa', ' Gastrointestinal ulcerc', ' Rectal haemorrhage']
# Item 1 :
# Item 2 :
# Item 3 :
# Item 4 : Gallbladder
# perforationb,c
# AR list:  ['Gallbladder perforationb']
# The table:  3 1st Row:  0    System organ \nclass
# 1             Very common
# 2                  Common
# 3                    Rare
# 4               Not known
# Name: 0, dtype: object
# The table:  3 Len 1st Row:  5
# Case B: Table has frequencies in the first row
# Frequencies:  {1: 'Very common', 2: 'Common', 3: 'Rare', 4: 'Not known'}
# Item 1 :
# Item 2 : Wound healing
# complicationsa,b,
# Palmar-plantar
# erythrodysaesthesia
# syndrome
# AR list:  ['Wound healing complicationsa', ' Palmar-plantar erythrodysaesthesia syndrome']
# Item 3 :
# Item 4 :
# Item 1 :
# Item 2 : Fistulaa,b, Myalgia,
# Arthralgia, Muscular
# weakness, Back Pain
# AR list:  ['Fistulaa', ' Myalgia', ' Arthralgia', ' Muscular weakness', ' Back Pain']
# Item 3 :
# Item 4 : Osteonecrosis of the
# jawb,c
# AR list:  ['Osteonecrosis of the jawb']
# Item 1 :
# Item 2 : Proteinuriaa,b
# AR list:  ['Proteinuriaa']
# Item 3 :
# Item 4 :
# Item 1 :
# Item 2 : Pelvic pain
# AR list:  ['Pelvic pain']
# Item 3 :
# Item 4 : Ovarian failurea,b
# AR list:  ['Ovarian failurea']
# Item 1 :
# Item 2 :
# Item 3 :
# Item 4 : Foetal
# abnormalitiesa,c
# AR list:  ['Foetal abnormalitiesa']
# Item 1 : Asthenia, Fatigue
# AR list:  ['Asthenia', ' Fatigue']
# Item 2 : Pain, Lethargy,
# Mucosal Inflammation
# AR list:  ['Pain', ' Lethargy', ' Mucosal Inflammation']
# Item 3 :
# Item 4 :
# The table:  4 1st Row:  0    MedDRA system organ \nclass (SOC)
# 1               Reactions (frequency*)
# Name: 0, dtype: object
# The table:  4 Len 1st Row:  2
# The table:  5 1st Row:  0    MedDRA system organ \nclass (SOC)
# 1               Reactions (frequency*)
# Name: 0, dtype: object
# The table:  5 Len 1st Row:  2
# /var/folders/ks/61tstkzx4rj7v0my891xbvx40000gn/T/ipykernel_41646/1307761050.py:53: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   elif df.iloc[0].astype(str).str.contains(freq_regex).any():
# /var/folders/ks/61tstkzx4rj7v0my891xbvx40000gn/T/ipykernel_41646/1307761050.py:53: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   elif df.iloc[0].astype(str).str.contains(freq_regex).any():
# /var/folders/ks/61tstkzx4rj7v0my891xbvx40000gn/T/ipykernel_41646/1307761050.py:53: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   elif df.iloc[0].astype(str).str.contains(freq_regex).any():
# /var/folders/ks/61tstkzx4rj7v0my891xbvx40000gn/T/ipykernel_41646/1307761050.py:53: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   elif df.iloc[0].astype(str).str.contains(freq_regex).any():
# /var/folders/ks/61tstkzx4rj7v0my891xbvx40000gn/T/ipykernel_41646/1307761050.py:53: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   elif df.iloc[0].astype(str).str.contains(freq_regex).any():
# /var/folders/ks/61tstkzx4rj7v0my891xbvx40000gn/T/ipykernel_41646/1307761050.py:53: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   elif df.iloc[0].astype(str).str.contains(freq_regex).any():

# %%
dict = {0: 'System organ \nclass', 1: 'Very common', 2: 'Common', 3: 'Rare'}

# %%
dict.pop(0)
# Out:
# 'System organ \nclass'

# %%
dict
# Out:
# {1: 'Very common', 2: 'Common', 3: 'Rare'}

# %%
dict[1] * 3
# Out:
# 'Very commonVery commonVery common'

# %%
[dict[1]  for _ in range(3)]
# Out:
# ['Very common', 'Very common', 'Very common']
